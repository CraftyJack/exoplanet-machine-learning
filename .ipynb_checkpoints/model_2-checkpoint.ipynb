# %%
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.

# column definitions can be found here: https://exoplanetarchive.ipac.caltech.edu/docs/API_kepcandidate_columns.html
# we'll exclude all the second error terms, as well as the disposition
column_names = list(df.columns.values)

exclusion_list = ['koi_disposition', '_err2',]
selected_columns = [x for x in column_names if all(y not in x for y in exclusion_list)]

selected_features = df[selected_columns]

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
X = selected_features
y = df.koi_disposition

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
X_train.shape, y_train.shape
# Out:
# ((5243, 30), (5243,))

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 3563              0              0              0              0   10.548413
# 4099              0              0              0              0   24.754385
# 5460              0              0              0              0    1.057336
# 1091              0              0              0              0  201.118319
# 5999              0              0              0              0   91.649983
#
#       koi_period_err1  koi_time0bk  koi_time0bk_err1  koi_impact  \
# 3563     5.470000e-05   139.064020          0.004110      1.0170
# 4099     1.365000e-04   140.207320          0.004460      0.7090
# 5460     1.230000e-07   131.792007          0.000096      0.2620
# 1091     1.461000e-03   187.569860          0.005290      0.0010
# 5999     3.181000e-03   175.715600          0.028600      0.2136
#
#       koi_impact_err1  ...  koi_tce_plnt_num  koi_steff  koi_steff_err1  \
# 3563           0.0470  ...                 2       6047             120
# 4099           0.0230  ...                 1       4852             144
# 5460           0.2740  ...                 1       4664             126
# 1091           0.4170  ...                 1       5646             101
# 5999           0.2282  ...                 2       6705             164
#
#       koi_slogg  koi_slogg_err1  koi_srad  koi_srad_err1         ra  \
# 3563      4.387           0.066     1.092          0.181  298.09543
# 4099      4.519           0.078     0.804          0.056  295.73535
# 5460      4.594           0.054     0.683          0.054  292.18417
# 1091      4.447           0.072     0.954          0.135  283.11377
# 5999      4.145           0.164     1.608          0.905  294.93198
#
#             dec  koi_kepmag
# 3563  44.737061      13.204
# 4099  42.576248      15.514
# 5460  49.310040      15.414
# 1091  48.131390      13.328
# 5999  39.812420      12.964
#
# [5 rows x 30 columns]

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data
from sklearn.preprocessing import LabelEncoder, StandardScaler
X_scaler = StandardScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Create LogisticRegression Model

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(max_iter = 1000)

# %% [markdown]
# # Train the Model

# %%
classifier.fit(X_train_scaled, y_train)
coef = classifier.coef_[0]
classifier
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
col_names = X.columns
summary_df = pd.DataFrame({'feature_name': col_names, 'correl': coef})
summary_df.sort_values(['correl'], ascending=False)
# Out:
#          feature_name    correl
# 11  koi_duration_err1  1.943603
# 12          koi_depth  1.353314
# 4          koi_period  0.304848
# 15      koi_prad_err1  0.303180
# 18     koi_insol_err1  0.302343
# 8          koi_impact  0.299154
# 7    koi_time0bk_err1  0.162135
# 16            koi_teq  0.151178
# 26      koi_srad_err1  0.140236
# 25           koi_srad  0.083111
# 13     koi_depth_err1  0.077810
# 9     koi_impact_err1  0.048876
# 27                 ra  0.047036
# 6         koi_time0bk  0.039694
# 14           koi_prad  0.012110
# 22     koi_steff_err1  0.003680
# 20   koi_tce_plnt_num -0.012872
# 28                dec -0.045932
# 21          koi_steff -0.073302
# 29         koi_kepmag -0.075868
# 24     koi_slogg_err1 -0.148726
# 23          koi_slogg -0.164857
# 17          koi_insol -0.197320
# 19      koi_model_snr -0.235249
# 5     koi_period_err1 -0.262131
# 10       koi_duration -0.945393
# 1       koi_fpflag_ss -1.167874
# 3       koi_fpflag_ec -1.244850
# 2       koi_fpflag_co -1.908006
# 0       koi_fpflag_nt -2.123648

# %%
print(f"Training Data Score: {classifier.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.8849895098226206
# Testing Data Score: 0.8981693363844394

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV
import numpy as np

C = [1, 5, 10, 50, 100]

param_grid = dict(C=C)

grid = GridSearchCV(classifier, param_grid, cv=5, verbose=3)

# %%
# Train the model with GridSearch
grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV] C=1 .............................................................
# [CV] ................................. C=1, score=0.885, total=   0.2s
# [CV] C=1 .............................................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [CV] ................................. C=1, score=0.887, total=   0.2s
# [CV] C=1 .............................................................
# [CV] ................................. C=1, score=0.880, total=   0.1s
# [CV] C=1 .............................................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.2s remaining:    0.0s
# [CV] ................................. C=1, score=0.881, total=   0.1s
# [CV] C=1 .............................................................
# [CV] ................................. C=1, score=0.871, total=   0.1s
# [CV] C=5 .............................................................
# [CV] ................................. C=5, score=0.890, total=   0.3s
# [CV] C=5 .............................................................
# [CV] ................................. C=5, score=0.886, total=   0.2s
# [CV] C=5 .............................................................
# [CV] ................................. C=5, score=0.883, total=   0.3s
# [CV] C=5 .............................................................
# [CV] ................................. C=5, score=0.878, total=   0.3s
# [CV] C=5 .............................................................
# [CV] ................................. C=5, score=0.868, total=   0.3s
# [CV] C=10 ............................................................
# [CV] ................................ C=10, score=0.889, total=   0.4s
# [CV] C=10 ............................................................
# [CV] ................................ C=10, score=0.887, total=   0.3s
# [CV] C=10 ............................................................
# [CV] ................................ C=10, score=0.885, total=   0.3s
# [CV] C=10 ............................................................
# [CV] ................................ C=10, score=0.877, total=   0.3s
# [CV] C=10 ............................................................
# [CV] ................................ C=10, score=0.866, total=   0.4s
# [CV] C=50 ............................................................
# [CV] ................................ C=50, score=0.887, total=   0.4s
# [CV] C=50 ............................................................
# [CV] ................................ C=50, score=0.888, total=   0.5s
# [CV] C=50 ............................................................
# [CV] ................................ C=50, score=0.887, total=   0.7s
# [CV] C=50 ............................................................
# [CV] ................................ C=50, score=0.878, total=   0.5s
# [CV] C=50 ............................................................
# [CV] ................................ C=50, score=0.867, total=   0.5s
# [CV] C=100 ...........................................................
# [CV] ............................... C=100, score=0.888, total=   0.8s
# [CV] C=100 ...........................................................
# [CV] ............................... C=100, score=0.888, total=   0.7s
# [CV] C=100 ...........................................................
# [CV] ............................... C=100, score=0.887, total=   0.8s
# [CV] C=100 ...........................................................
# [CV] ............................... C=100, score=0.878, total=   0.8s
# [CV] C=100 ...........................................................
# [CV] ............................... C=100, score=0.866, total=   0.7s
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed:   10.2s finished
# GridSearchCV(cv=5, error_score=nan,
#              estimator=LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                           fit_intercept=True,
#                                           intercept_scaling=1, l1_ratio=None,
#                                           max_iter=1000, multi_class='auto',
#                                           n_jobs=None, penalty='l2',
#                                           random_state=None, solver='lbfgs',
#                                           tol=0.0001, verbose=0,
#                                           warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'C': [1, 5, 10, 50, 100]}, pre_dispatch='2*n_jobs',
#              refit=True, return_train_score=False, scoring=None, verbose=3)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'C': 100}
# 0.88136211149841

# %%
predictions = grid.predict(X_test_scaled)
print('Test Acc: %.3f' % grid.score(X_test_scaled, y_test))
# Out:
# Test Acc: 0.898

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions,
                            target_names=y_test.unique()))
# Out:
#                 precision    recall  f1-score   support
#
#      CONFIRMED       0.87      0.69      0.77       404
# FALSE POSITIVE       0.75      0.90      0.82       435
#      CANDIDATE       0.99      0.99      0.99       909
#
#       accuracy                           0.90      1748
#      macro avg       0.87      0.86      0.86      1748
#   weighted avg       0.90      0.90      0.90      1748

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'koi_logreg_model.sav'
joblib.dump(grid, filename)
# Out:
# ['koi_logreg_model.sav']
